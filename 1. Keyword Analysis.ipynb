# %% [markdown]
# # Keyword analysis can help you to define:
# * Trending searches daily for country
# * Annula trend for country ( ex. Italy )
# * Daily trend
# * Global keyword interest
# * Interest by Italian region - 12 Months tranding
# * Google Keyword Suggestions by Topic
# * Interest by Region with Multiple Keywords
# * Interest by Region - 3 words
# * Related queries
# * Comparison of two annual Trends in Italy
# * Comparison of keywords in two different states
# * Trending Searches
# * Interest for Keywords by Region
# * Related Topics / Related Queries
# * Interest for two words over a period of 5 years
# * Interest for one or more words on a regional basis, city-wise, by region, and metropolitan area.

# %% [markdown]
# In this project we display only some type of analysis, which can help us outline a market trend based on the name of the fashion brands and different types of bags.

# %% [markdown]
# <h2 style='text-align: center;'> Interest by Region with Multiple Keywords </h2>

# %%
# Out:
# Per favore inserisci una o più parole separate da virgola per ottenere i trends nelle regioni italiane, come ad esempio: armadio, sediaborsa donna, pochette
#                                  borsa donna  pochette
# geoName
# Basilicata                                34         66
# Molise                                    34         66
# Trentino-Alto Adige/South Tyrol           32         68
# Piedmont                                  32         68
# Friuli-Venezia Giulia                     31         69
# Umbria                                    30         70
# Marche                                    29         71
# Sardinia                                  29         71
# Liguria                                   29         71
# Lombardy                                  28         72
# Tuscany                                   28         72
# Veneto                                    28         72
# Emilia-Romagna                            28         72
# ...

# %% [markdown]
# <h2 style='text-align: center;'> Interest by Region with Multiple Keywords </h2>

# %% [markdown]
# <h2 style='text-align: center;'> Related queries </h2>

# %%
# Out:
#                        top query  top query value  \
# 0         louis vuitton pochette              100
# 1                  louis vuitton              100
# 2               pochette vuitton               93
# 3                             lv               38
# 4                    pochette lv               37
# 5                 multi pochette               32
# 6                 pochette metis               29
# 7                   sac pochette               27
# 8                   pochette bag               22
# 9                  mini pochette               21
# 10                pochette femme               18
# 11  louis vuitton multi pochette               18
# 12                pochette homme               14
# 13                pochette gucci               14
# 14  pochette metis louis vuitton               14
# 15  louis vuitton metis pochette               14
# 16          pochette accessoires               14
# 17                         gucci               13
# ...

# %% [markdown]
# <h2 style='text-align: center;'> Italian anual Trend by two Keyword </h2>

# %%
# Out:
# Inserire 2 keyword per visualizzare la loro ricerca annuale in Italia separate da una virgola: pochette valentino, pochette lv

# %%
# Out:
# Inserire 1 keyword per visualizzare la ricerca annuale in Italia: vestito valentino

# %% [markdown]
# <h2 style='text-align: center;'> Comparison of the same keywords for two different countries </h2>

# %% [markdown]
# <h2 style='text-align: center;'> Trend Data of Interest for Keywords by Region </h2>

# %%
# Out:
#                     dolce e gabbana  valentino  gucci  louis vuitton  Total
# geoName
# Argentina                         0         35     46             19    100
# Morocco                           0         11     48             41    100
# United States                     0          6     57             37    100
# United Kingdom                    0         12     58             30    100
# Türkiye                           0         14     54             32    100
# Switzerland                       0         14     44             42    100
# Spain                             0         20     47             33    100
# South Africa                      0          6     62             32    100
# Slovakia                          0         17     57             26    100
# Russia                            0         11     57             32    100
# Romania                           0         20     55             25    100
# ...

# %% [markdown]
# <h2 style='text-align: center;'> Related queries /Topics </h2>

# %%
# Out:
#                            top query  top query value  \
# 0               dolce e gabbana uomo              100
# 1             dolce e gabbana scarpe               74
# 2           dolce di dolce e gabbana               69
# 3            dolce e gabbana profumo               65
# 4              dolce e gabbana donna               59
# 5           dolce e gabbana occhiali               54
# 6         dolce e gabbana light blue               43
# 7           dolce gabbana light blue               41
# 8                              gucci               39
# 9            dolce e gabbana the one               34
# 10             dolce gabbana the one               31
# 11        pubblicità dolce e gabbana               23
# 12       dolce e gabbana scarpe uomo               23
# 13                        pubblicità               22
# 14                           versace               22
# 15                  occhiali da sole               18
# ...
